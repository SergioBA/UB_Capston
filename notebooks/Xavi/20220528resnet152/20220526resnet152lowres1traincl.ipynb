# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_addons as tfa

# %%
import keras.models
import keras.layers
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
import numpy as np

# %%
dirsplit0 = "../20220408CAPSULE_DATA/splits/splitslowres/split_0/"

# %%
dirsplit1 = "../20220408CAPSULE_DATA/splits/splitslowres/split_1/"

# %%
#os.listdir(dirsplit0)

# %%
#os.listdir(dirsplit1)

# %%
train_datagen = ImageDataGenerator()

# %%
TRAINING_DIR = dirsplit1
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    class_mode='categorical',
                                                    target_size=(168, 168))
# Out:
# Found 24100 images belonging to 11 classes.

# %%
validation_datagen = ImageDataGenerator()

# %%
VALIDATION_DIR = dirsplit0
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              class_mode='categorical',
                                                              target_size=(168, 168))
# Out:
# Found 23061 images belonging to 11 classes.

# %%
# for ims, labs in train_generator:
#     print(ims.shape)
#     break

# %% [markdown]
# ## ResNet152

# %%
#from tensorflow.keras.applications.resnet50 import ResNet50

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_MatthewsCorrelationCoefficient', patience=3)

# %%
from tensorflow.keras.applications.resnet import ResNet152

# %%
pre_trained_model = ResNet152(input_shape=(168,168,3), include_top=False, weights= 'imagenet', pooling='avg')
# Out:
# 2022-05-28 11:22:04.716881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:04.762213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:04.762474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:04.764041: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:04.764253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:04.764447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:05.407571: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:05.407796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:05.407983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 11:22:05.408134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2998 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1

# %%
for layer in pre_trained_model.layers:  
    layer.trainable=False

# %%
last_layer = pre_trained_model.get_layer('conv4_block6_out')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 11, 11, 1024)

# %%
inputs = keras.layers.Input((168, 168, 3))
x = tf.keras.applications.resnet50.preprocess_input(inputs) # Preprocessing layer, normalization -1 1
x = pre_trained_model(x)

## Aquestes capes son opcionals
x = keras.layers.Dropout(0.4)(x)      
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dropout(0.2)(x)   

out = keras.layers.Dense(11, activation='softmax')(x)           
model = keras.Model(inputs=inputs, outputs=out) 

model.compile(optimizer = tf.optimizers.SGD(learning_rate=0.001),
              loss = tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy(), 
                       tfa.metrics.F1Score(num_classes=11, average="micro"), 
                       tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), 
                       tfa.metrics.MatthewsCorrelationCoefficient(num_classes=11)])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 168, 168, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 168, 168, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 168, 168, 3)      0
#
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 58,898,315
# Trainable params: 527,371
# Non-trainable params: 58,370,944
# _________________________________________________________________

# %%
history_resnet = model.fit(train_generator,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/30
# 2022-05-28 11:22:45.593978: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 754/754 [==============================] - 575s 745ms/step - loss: 0.9191 - categorical_accuracy: 0.7628 - f1_score: 0.7628 - precision: 0.8175 - recall: 0.7130 - MatthewsCorrelationCoefficient: 0.2537 - val_loss: 1.2442 - val_categorical_accuracy: 0.6992 - val_f1_score: 0.6992 - val_precision: 0.7317 - val_recall: 0.6787 - val_MatthewsCorrelationCoefficient: 0.2162
# Epoch 2/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.6616 - categorical_accuracy: 0.8096 - f1_score: 0.8096 - precision: 0.8605 - recall: 0.7654 - MatthewsCorrelationCoefficient: 0.4342 - val_loss: 1.1900 - val_categorical_accuracy: 0.6999 - val_f1_score: 0.6999 - val_precision: 0.7455 - val_recall: 0.6710 - val_MatthewsCorrelationCoefficient: 0.2353
# Epoch 3/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.5881 - categorical_accuracy: 0.8281 - f1_score: 0.8281 - precision: 0.8728 - recall: 0.7853 - MatthewsCorrelationCoefficient: 0.5031 - val_loss: 1.1914 - val_categorical_accuracy: 0.7008 - val_f1_score: 0.7008 - val_precision: 0.7469 - val_recall: 0.6717 - val_MatthewsCorrelationCoefficient: 0.2433
# Epoch 4/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.5370 - categorical_accuracy: 0.8408 - f1_score: 0.8408 - precision: 0.8798 - recall: 0.8018 - MatthewsCorrelationCoefficient: 0.5463 - val_loss: 1.2181 - val_categorical_accuracy: 0.6999 - val_f1_score: 0.6999 - val_precision: 0.7513 - val_recall: 0.6680 - val_MatthewsCorrelationCoefficient: 0.2513
# Epoch 5/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.5017 - categorical_accuracy: 0.8500 - f1_score: 0.8500 - precision: 0.8856 - recall: 0.8141 - MatthewsCorrelationCoefficient: 0.5790 - val_loss: 1.2251 - val_categorical_accuracy: 0.6979 - val_f1_score: 0.6979 - val_precision: 0.7528 - val_recall: 0.6646 - val_MatthewsCorrelationCoefficient: 0.2561
# Epoch 6/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.4752 - categorical_accuracy: 0.8571 - f1_score: 0.8571 - precision: 0.8898 - recall: 0.8254 - MatthewsCorrelationCoefficient: 0.6005 - val_loss: 1.2219 - val_categorical_accuracy: 0.7008 - val_f1_score: 0.7008 - val_precision: 0.7455 - val_recall: 0.6710 - val_MatthewsCorrelationCoefficient: 0.2571
# Epoch 7/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.4543 - categorical_accuracy: 0.8647 - f1_score: 0.8647 - precision: 0.8963 - recall: 0.8334 - MatthewsCorrelationCoefficient: 0.6252 - val_loss: 1.2628 - val_categorical_accuracy: 0.6987 - val_f1_score: 0.6987 - val_precision: 0.7433 - val_recall: 0.6723 - val_MatthewsCorrelationCoefficient: 0.2599
# Epoch 8/30
# 754/754 [==============================] - 554s 734ms/step - loss: 0.4389 - categorical_accuracy: 0.8663 - f1_score: 0.8663 - precision: 0.8961 - recall: 0.8385 - MatthewsCorrelationCoefficient: 0.6312 - val_loss: 1.2650 - val_categorical_accuracy: 0.6975 - val_f1_score: 0.6975 - val_precision: 0.7440 - val_recall: 0.6687 - val_MatthewsCorrelationCoefficient: 0.2633
# Epoch 9/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.4232 - categorical_accuracy: 0.8722 - f1_score: 0.8722 - precision: 0.9010 - recall: 0.8447 - MatthewsCorrelationCoefficient: 0.6493 - val_loss: 1.2538 - val_categorical_accuracy: 0.6939 - val_f1_score: 0.6939 - val_precision: 0.7441 - val_recall: 0.6606 - val_MatthewsCorrelationCoefficient: 0.2649
# Epoch 10/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.4122 - categorical_accuracy: 0.8771 - f1_score: 0.8771 - precision: 0.9033 - recall: 0.8500 - MatthewsCorrelationCoefficient: 0.6637 - val_loss: 1.2513 - val_categorical_accuracy: 0.6936 - val_f1_score: 0.6936 - val_precision: 0.7420 - val_recall: 0.6652 - val_MatthewsCorrelationCoefficient: 0.2653
# Epoch 11/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3969 - categorical_accuracy: 0.8801 - f1_score: 0.8801 - precision: 0.9057 - recall: 0.8557 - MatthewsCorrelationCoefficient: 0.6741 - val_loss: 1.2676 - val_categorical_accuracy: 0.6961 - val_f1_score: 0.6961 - val_precision: 0.7414 - val_recall: 0.6694 - val_MatthewsCorrelationCoefficient: 0.2583
# Epoch 12/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3875 - categorical_accuracy: 0.8825 - f1_score: 0.8825 - precision: 0.9067 - recall: 0.8596 - MatthewsCorrelationCoefficient: 0.6818 - val_loss: 1.2817 - val_categorical_accuracy: 0.6942 - val_f1_score: 0.6942 - val_precision: 0.7391 - val_recall: 0.6682 - val_MatthewsCorrelationCoefficient: 0.2641
# Epoch 13/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3763 - categorical_accuracy: 0.8844 - f1_score: 0.8844 - precision: 0.9085 - recall: 0.8610 - MatthewsCorrelationCoefficient: 0.6866 - val_loss: 1.2926 - val_categorical_accuracy: 0.6933 - val_f1_score: 0.6933 - val_precision: 0.7384 - val_recall: 0.6694 - val_MatthewsCorrelationCoefficient: 0.2688
# Epoch 14/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3659 - categorical_accuracy: 0.8880 - f1_score: 0.8880 - precision: 0.9103 - recall: 0.8660 - MatthewsCorrelationCoefficient: 0.6971 - val_loss: 1.2787 - val_categorical_accuracy: 0.6898 - val_f1_score: 0.6898 - val_precision: 0.7388 - val_recall: 0.6636 - val_MatthewsCorrelationCoefficient: 0.2668
# Epoch 15/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3611 - categorical_accuracy: 0.8904 - f1_score: 0.8904 - precision: 0.9117 - recall: 0.8688 - MatthewsCorrelationCoefficient: 0.7048 - val_loss: 1.2873 - val_categorical_accuracy: 0.6932 - val_f1_score: 0.6932 - val_precision: 0.7349 - val_recall: 0.6711 - val_MatthewsCorrelationCoefficient: 0.2634
# Epoch 16/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3544 - categorical_accuracy: 0.8922 - f1_score: 0.8922 - precision: 0.9127 - recall: 0.8716 - MatthewsCorrelationCoefficient: 0.7101 - val_loss: 1.2858 - val_categorical_accuracy: 0.6914 - val_f1_score: 0.6914 - val_precision: 0.7369 - val_recall: 0.6682 - val_MatthewsCorrelationCoefficient: 0.2670
# Epoch 17/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3427 - categorical_accuracy: 0.8959 - f1_score: 0.8959 - precision: 0.9168 - recall: 0.8770 - MatthewsCorrelationCoefficient: 0.7210 - val_loss: 1.3196 - val_categorical_accuracy: 0.6910 - val_f1_score: 0.6910 - val_precision: 0.7359 - val_recall: 0.6684 - val_MatthewsCorrelationCoefficient: 0.2612
# Epoch 18/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3369 - categorical_accuracy: 0.8994 - f1_score: 0.8994 - precision: 0.9184 - recall: 0.8793 - MatthewsCorrelationCoefficient: 0.7310 - val_loss: 1.2817 - val_categorical_accuracy: 0.6891 - val_f1_score: 0.6891 - val_precision: 0.7356 - val_recall: 0.6656 - val_MatthewsCorrelationCoefficient: 0.2659
# Epoch 19/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3330 - categorical_accuracy: 0.8983 - f1_score: 0.8983 - precision: 0.9185 - recall: 0.8798 - MatthewsCorrelationCoefficient: 0.7276 - val_loss: 1.3082 - val_categorical_accuracy: 0.6912 - val_f1_score: 0.6912 - val_precision: 0.7332 - val_recall: 0.6685 - val_MatthewsCorrelationCoefficient: 0.2624
# Epoch 20/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3248 - categorical_accuracy: 0.9002 - f1_score: 0.9002 - precision: 0.9193 - recall: 0.8815 - MatthewsCorrelationCoefficient: 0.7334 - val_loss: 1.2925 - val_categorical_accuracy: 0.6868 - val_f1_score: 0.6868 - val_precision: 0.7381 - val_recall: 0.6618 - val_MatthewsCorrelationCoefficient: 0.2713
# Epoch 21/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3205 - categorical_accuracy: 0.9021 - f1_score: 0.9021 - precision: 0.9212 - recall: 0.8838 - MatthewsCorrelationCoefficient: 0.7388 - val_loss: 1.3152 - val_categorical_accuracy: 0.6918 - val_f1_score: 0.6918 - val_precision: 0.7356 - val_recall: 0.6700 - val_MatthewsCorrelationCoefficient: 0.2652
# Epoch 22/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3137 - categorical_accuracy: 0.9041 - f1_score: 0.9041 - precision: 0.9230 - recall: 0.8874 - MatthewsCorrelationCoefficient: 0.7449 - val_loss: 1.3329 - val_categorical_accuracy: 0.6923 - val_f1_score: 0.6923 - val_precision: 0.7337 - val_recall: 0.6716 - val_MatthewsCorrelationCoefficient: 0.2680
# Epoch 23/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3077 - categorical_accuracy: 0.9069 - f1_score: 0.9069 - precision: 0.9251 - recall: 0.8905 - MatthewsCorrelationCoefficient: 0.7527 - val_loss: 1.3223 - val_categorical_accuracy: 0.6910 - val_f1_score: 0.6910 - val_precision: 0.7327 - val_recall: 0.6700 - val_MatthewsCorrelationCoefficient: 0.2647
# Epoch 24/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.3074 - categorical_accuracy: 0.9057 - f1_score: 0.9057 - precision: 0.9239 - recall: 0.8900 - MatthewsCorrelationCoefficient: 0.7495 - val_loss: 1.3197 - val_categorical_accuracy: 0.6909 - val_f1_score: 0.6909 - val_precision: 0.7320 - val_recall: 0.6683 - val_MatthewsCorrelationCoefficient: 0.2656
# Epoch 25/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2972 - categorical_accuracy: 0.9101 - f1_score: 0.9101 - precision: 0.9279 - recall: 0.8938 - MatthewsCorrelationCoefficient: 0.7615 - val_loss: 1.2925 - val_categorical_accuracy: 0.6798 - val_f1_score: 0.6798 - val_precision: 0.7344 - val_recall: 0.6543 - val_MatthewsCorrelationCoefficient: 0.2683
# Epoch 26/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2990 - categorical_accuracy: 0.9084 - f1_score: 0.9084 - precision: 0.9270 - recall: 0.8926 - MatthewsCorrelationCoefficient: 0.7571 - val_loss: 1.3202 - val_categorical_accuracy: 0.6897 - val_f1_score: 0.6897 - val_precision: 0.7323 - val_recall: 0.6682 - val_MatthewsCorrelationCoefficient: 0.2689
# Epoch 27/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2958 - categorical_accuracy: 0.9094 - f1_score: 0.9094 - precision: 0.9253 - recall: 0.8936 - MatthewsCorrelationCoefficient: 0.7600 - val_loss: 1.3215 - val_categorical_accuracy: 0.6905 - val_f1_score: 0.6905 - val_precision: 0.7339 - val_recall: 0.6689 - val_MatthewsCorrelationCoefficient: 0.2709
# Epoch 28/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2869 - categorical_accuracy: 0.9125 - f1_score: 0.9125 - precision: 0.9286 - recall: 0.8971 - MatthewsCorrelationCoefficient: 0.7689 - val_loss: 1.3363 - val_categorical_accuracy: 0.6913 - val_f1_score: 0.6913 - val_precision: 0.7344 - val_recall: 0.6719 - val_MatthewsCorrelationCoefficient: 0.2700
# Epoch 29/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2875 - categorical_accuracy: 0.9119 - f1_score: 0.9119 - precision: 0.9294 - recall: 0.8969 - MatthewsCorrelationCoefficient: 0.7672 - val_loss: 1.3141 - val_categorical_accuracy: 0.6900 - val_f1_score: 0.6900 - val_precision: 0.7365 - val_recall: 0.6665 - val_MatthewsCorrelationCoefficient: 0.2772
# Epoch 30/30
# 754/754 [==============================] - 554s 735ms/step - loss: 0.2812 - categorical_accuracy: 0.9150 - f1_score: 0.9150 - precision: 0.9304 - recall: 0.8996 - MatthewsCorrelationCoefficient: 0.7756 - val_loss: 1.3113 - val_categorical_accuracy: 0.6899 - val_f1_score: 0.6899 - val_precision: 0.7338 - val_recall: 0.6679 - val_MatthewsCorrelationCoefficient: 0.2722

# %%
# evaluate the model
loss, accuracy, f1_score, precision, recall, MCC = model.evaluate(validation_generator, verbose=0)

# %%
print ("loss =",loss,"accuracy=",accuracy,"f1=",f1_score,"precision",precision,"recall",recall,"MCC",MCC)
# Out:
# loss = 1.311339020729065 accuracy= 0.6898660063743591 f1= 0.6898660063743591 precision 0.7337906956672668 recall 0.6679242253303528 MCC 0.27224239706993103

# %%
model.save('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train1lowres30epochmodelsaved')
# Out:
# 2022-05-28 16:46:40.976369: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train1lowres30epochmodelsaved/assets

# %%
#model = keras.models.load_model('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train1lowres30epochmodelsaved')

# %%
history_resnet.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'f1_score', 'precision', 'recall', 'MatthewsCorrelationCoefficient', 'val_loss', 'val_categorical_accuracy', 'val_f1_score', 'val_precision', 'val_recall', 'val_MatthewsCorrelationCoefficient'])

# %%
ac = history_resnet.history['categorical_accuracy']
v_ac = history_resnet.history['val_categorical_accuracy']   
lo = history_resnet.history['loss']
v_lo = history_resnet.history['val_loss']
f = history_resnet.history['f1_score']
v_f = history_resnet.history['val_f1_score']
mcc = history_resnet.history['MatthewsCorrelationCoefficient']
v_mcc = history_resnet.history['val_MatthewsCorrelationCoefficient']
epochs = history_resnet.epoch

# %%
plt.figure(figsize=(10,5),frameon=False)
plt.plot(epochs,ac,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_ac,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Accuracy for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,lo,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_lo,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Loss for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,f,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_f,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('f1 for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('f1')
# Out:
# Text(0, 0.5, 'f1')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,mcc,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_mcc,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('MCC for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('MCC')
# Out:
# Text(0, 0.5, 'MCC')
