# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_addons as tfa

# %%
import keras.models
import keras.layers
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
import numpy as np

# %%
dirsplit0 = "../20220408CAPSULE_DATA/splits/splitslowres/split_0/"

# %%
dirsplit1 = "../20220408CAPSULE_DATA/splits/splitslowres/split_1/"

# %%
#os.listdir(dirsplit0)

# %%
#os.listdir(dirsplit1)

# %%
train_datagen = ImageDataGenerator()

# %%
TRAINING_DIR = dirsplit1
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    class_mode='categorical',
                                                    target_size=(168, 168))
# Out:
# Found 24100 images belonging to 11 classes.

# %%
validation_datagen = ImageDataGenerator()

# %%
VALIDATION_DIR = dirsplit0
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              class_mode='categorical',
                                                              target_size=(168, 168))
# Out:
# Found 23061 images belonging to 11 classes.

# %% [markdown]
# ## DenseNet169

# %%
#from tensorflow.keras.applications.resnet50 import ResNet50

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_MatthewsCorrelationCoefficient', patience=3)

# %%
from tensorflow.keras.applications.densenet import DenseNet169

# %%
pre_trained_model = DenseNet169(input_shape=(168,168,3),include_top =False, weights= 'imagenet', pooling='avg')
# Out:
# 2022-05-30 19:05:44.307313: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.352807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.353063: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.354676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.354894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.355107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.983999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.984220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.984406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-30 19:05:44.984559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3020 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1

# %%
for layer in pre_trained_model.layers:  
    layer.trainable=False

# %%
last_layer = pre_trained_model.get_layer('conv5_block32_concat')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 5, 5, 1664)

# %%
inputs = keras.layers.Input((168, 168, 3))
x = tf.keras.applications.densenet.preprocess_input(inputs) # Preprocessing layer, normalization -1 1
x = pre_trained_model(x)

## Aquestes capes son opcionals
x = keras.layers.Dropout(0.4)(x)      
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dropout(0.2)(x)   

out = keras.layers.Dense(11, activation='softmax')(x)           
model = keras.Model(inputs=inputs, outputs=out) 

model.compile(optimizer = tf.optimizers.SGD(learning_rate=0.001),
              loss = tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy(), 
                       tfa.metrics.F1Score(num_classes=11, average="micro"), 
                       tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), 
                       tfa.metrics.MatthewsCorrelationCoefficient(num_classes=11)])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 168, 168, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 168, 168, 3)      0
#  )
#
#  tf.nn.bias_add (TFOpLambda)  (None, 168, 168, 3)      0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 168, 168, 3)      0
#  da)
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dropout (Dropout)           (None, 1664)              0
#
#  dense (Dense)               (None, 256)               426240
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 13,071,947
# Trainable params: 429,067
# Non-trainable params: 12,642,880
# _________________________________________________________________

# %%
history_resnet = model.fit(train_generator,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/30
# 2022-05-30 19:06:15.492042: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 754/754 [==============================] - 243s 304ms/step - loss: 0.9097 - categorical_accuracy: 0.7643 - f1_score: 0.7643 - precision: 0.8232 - recall: 0.7078 - MatthewsCorrelationCoefficient: 0.2671 - val_loss: 1.2954 - val_categorical_accuracy: 0.7021 - val_f1_score: 0.7021 - val_precision: 0.7439 - val_recall: 0.6809 - val_MatthewsCorrelationCoefficient: 0.2411
# Epoch 2/30
# 754/754 [==============================] - 220s 291ms/step - loss: 0.6700 - categorical_accuracy: 0.8105 - f1_score: 0.8105 - precision: 0.8662 - recall: 0.7607 - MatthewsCorrelationCoefficient: 0.4405 - val_loss: 1.2460 - val_categorical_accuracy: 0.7032 - val_f1_score: 0.7032 - val_precision: 0.7572 - val_recall: 0.6723 - val_MatthewsCorrelationCoefficient: 0.2516
# Epoch 3/30
# 754/754 [==============================] - 222s 295ms/step - loss: 0.5978 - categorical_accuracy: 0.8278 - f1_score: 0.8278 - precision: 0.8759 - recall: 0.7822 - MatthewsCorrelationCoefficient: 0.5041 - val_loss: 1.2551 - val_categorical_accuracy: 0.7031 - val_f1_score: 0.7031 - val_precision: 0.7581 - val_recall: 0.6719 - val_MatthewsCorrelationCoefficient: 0.2542
# Epoch 4/30
# 754/754 [==============================] - 222s 295ms/step - loss: 0.5503 - categorical_accuracy: 0.8391 - f1_score: 0.8391 - precision: 0.8836 - recall: 0.7978 - MatthewsCorrelationCoefficient: 0.5427 - val_loss: 1.2702 - val_categorical_accuracy: 0.7010 - val_f1_score: 0.7010 - val_precision: 0.7552 - val_recall: 0.6733 - val_MatthewsCorrelationCoefficient: 0.2515
# Epoch 5/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.5153 - categorical_accuracy: 0.8495 - f1_score: 0.8495 - precision: 0.8893 - recall: 0.8099 - MatthewsCorrelationCoefficient: 0.5782 - val_loss: 1.2689 - val_categorical_accuracy: 0.7005 - val_f1_score: 0.7005 - val_precision: 0.7528 - val_recall: 0.6762 - val_MatthewsCorrelationCoefficient: 0.2525
# Epoch 6/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.4962 - categorical_accuracy: 0.8556 - f1_score: 0.8556 - precision: 0.8912 - recall: 0.8188 - MatthewsCorrelationCoefficient: 0.5978 - val_loss: 1.2566 - val_categorical_accuracy: 0.6973 - val_f1_score: 0.6973 - val_precision: 0.7570 - val_recall: 0.6715 - val_MatthewsCorrelationCoefficient: 0.2560
# Epoch 7/30
# 754/754 [==============================] - 221s 294ms/step - loss: 0.4763 - categorical_accuracy: 0.8582 - f1_score: 0.8582 - precision: 0.8932 - recall: 0.8246 - MatthewsCorrelationCoefficient: 0.6069 - val_loss: 1.2958 - val_categorical_accuracy: 0.6983 - val_f1_score: 0.6983 - val_precision: 0.7524 - val_recall: 0.6747 - val_MatthewsCorrelationCoefficient: 0.2539
# Epoch 8/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.4525 - categorical_accuracy: 0.8655 - f1_score: 0.8655 - precision: 0.8962 - recall: 0.8329 - MatthewsCorrelationCoefficient: 0.6291 - val_loss: 1.2768 - val_categorical_accuracy: 0.6967 - val_f1_score: 0.6967 - val_precision: 0.7505 - val_recall: 0.6744 - val_MatthewsCorrelationCoefficient: 0.2514
# Epoch 9/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.4415 - categorical_accuracy: 0.8654 - f1_score: 0.8654 - precision: 0.8987 - recall: 0.8359 - MatthewsCorrelationCoefficient: 0.6301 - val_loss: 1.2850 - val_categorical_accuracy: 0.6968 - val_f1_score: 0.6968 - val_precision: 0.7522 - val_recall: 0.6732 - val_MatthewsCorrelationCoefficient: 0.2613
# Epoch 10/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.4278 - categorical_accuracy: 0.8728 - f1_score: 0.8728 - precision: 0.9012 - recall: 0.8463 - MatthewsCorrelationCoefficient: 0.6521 - val_loss: 1.2874 - val_categorical_accuracy: 0.6950 - val_f1_score: 0.6950 - val_precision: 0.7515 - val_recall: 0.6712 - val_MatthewsCorrelationCoefficient: 0.2648
# Epoch 11/30
# 754/754 [==============================] - 219s 290ms/step - loss: 0.4159 - categorical_accuracy: 0.8761 - f1_score: 0.8761 - precision: 0.9030 - recall: 0.8500 - MatthewsCorrelationCoefficient: 0.6627 - val_loss: 1.2804 - val_categorical_accuracy: 0.6928 - val_f1_score: 0.6928 - val_precision: 0.7540 - val_recall: 0.6679 - val_MatthewsCorrelationCoefficient: 0.2612
# Epoch 12/30
# 754/754 [==============================] - 218s 289ms/step - loss: 0.4098 - categorical_accuracy: 0.8776 - f1_score: 0.8776 - precision: 0.9055 - recall: 0.8493 - MatthewsCorrelationCoefficient: 0.6665 - val_loss: 1.3173 - val_categorical_accuracy: 0.6977 - val_f1_score: 0.6977 - val_precision: 0.7487 - val_recall: 0.6779 - val_MatthewsCorrelationCoefficient: 0.2611
# Epoch 13/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3956 - categorical_accuracy: 0.8808 - f1_score: 0.8808 - precision: 0.9071 - recall: 0.8551 - MatthewsCorrelationCoefficient: 0.6764 - val_loss: 1.3165 - val_categorical_accuracy: 0.6948 - val_f1_score: 0.6948 - val_precision: 0.7463 - val_recall: 0.6746 - val_MatthewsCorrelationCoefficient: 0.2596
# Epoch 14/30
# 754/754 [==============================] - 219s 290ms/step - loss: 0.3893 - categorical_accuracy: 0.8818 - f1_score: 0.8818 - precision: 0.9082 - recall: 0.8567 - MatthewsCorrelationCoefficient: 0.6798 - val_loss: 1.3340 - val_categorical_accuracy: 0.6955 - val_f1_score: 0.6955 - val_precision: 0.7456 - val_recall: 0.6770 - val_MatthewsCorrelationCoefficient: 0.2565
# Epoch 15/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3896 - categorical_accuracy: 0.8822 - f1_score: 0.8822 - precision: 0.9084 - recall: 0.8580 - MatthewsCorrelationCoefficient: 0.6811 - val_loss: 1.3096 - val_categorical_accuracy: 0.6956 - val_f1_score: 0.6956 - val_precision: 0.7494 - val_recall: 0.6744 - val_MatthewsCorrelationCoefficient: 0.2658
# Epoch 16/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3745 - categorical_accuracy: 0.8877 - f1_score: 0.8877 - precision: 0.9127 - recall: 0.8639 - MatthewsCorrelationCoefficient: 0.6970 - val_loss: 1.3237 - val_categorical_accuracy: 0.6958 - val_f1_score: 0.6958 - val_precision: 0.7499 - val_recall: 0.6732 - val_MatthewsCorrelationCoefficient: 0.2714
# Epoch 17/30
# 754/754 [==============================] - 219s 290ms/step - loss: 0.3662 - categorical_accuracy: 0.8901 - f1_score: 0.8901 - precision: 0.9143 - recall: 0.8654 - MatthewsCorrelationCoefficient: 0.7044 - val_loss: 1.3427 - val_categorical_accuracy: 0.6962 - val_f1_score: 0.6962 - val_precision: 0.7459 - val_recall: 0.6764 - val_MatthewsCorrelationCoefficient: 0.2636
# Epoch 18/30
# 754/754 [==============================] - 218s 289ms/step - loss: 0.3663 - categorical_accuracy: 0.8901 - f1_score: 0.8901 - precision: 0.9123 - recall: 0.8678 - MatthewsCorrelationCoefficient: 0.7040 - val_loss: 1.3303 - val_categorical_accuracy: 0.6972 - val_f1_score: 0.6972 - val_precision: 0.7496 - val_recall: 0.6771 - val_MatthewsCorrelationCoefficient: 0.2729
# Epoch 19/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3587 - categorical_accuracy: 0.8890 - f1_score: 0.8890 - precision: 0.9126 - recall: 0.8678 - MatthewsCorrelationCoefficient: 0.7020 - val_loss: 1.3139 - val_categorical_accuracy: 0.6949 - val_f1_score: 0.6949 - val_precision: 0.7505 - val_recall: 0.6706 - val_MatthewsCorrelationCoefficient: 0.2749
# Epoch 20/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3516 - categorical_accuracy: 0.8933 - f1_score: 0.8933 - precision: 0.9163 - recall: 0.8719 - MatthewsCorrelationCoefficient: 0.7141 - val_loss: 1.3341 - val_categorical_accuracy: 0.6971 - val_f1_score: 0.6971 - val_precision: 0.7461 - val_recall: 0.6794 - val_MatthewsCorrelationCoefficient: 0.2643
# Epoch 21/30
# 754/754 [==============================] - 219s 290ms/step - loss: 0.3475 - categorical_accuracy: 0.8950 - f1_score: 0.8950 - precision: 0.9152 - recall: 0.8744 - MatthewsCorrelationCoefficient: 0.7184 - val_loss: 1.3458 - val_categorical_accuracy: 0.6972 - val_f1_score: 0.6972 - val_precision: 0.7466 - val_recall: 0.6789 - val_MatthewsCorrelationCoefficient: 0.2721
# Epoch 22/30
# 754/754 [==============================] - 218s 290ms/step - loss: 0.3444 - categorical_accuracy: 0.8952 - f1_score: 0.8952 - precision: 0.9164 - recall: 0.8738 - MatthewsCorrelationCoefficient: 0.7198 - val_loss: 1.3444 - val_categorical_accuracy: 0.6957 - val_f1_score: 0.6957 - val_precision: 0.7443 - val_recall: 0.6775 - val_MatthewsCorrelationCoefficient: 0.2672
# Epoch 23/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.3374 - categorical_accuracy: 0.8961 - f1_score: 0.8961 - precision: 0.9179 - recall: 0.8769 - MatthewsCorrelationCoefficient: 0.7224 - val_loss: 1.3523 - val_categorical_accuracy: 0.6956 - val_f1_score: 0.6956 - val_precision: 0.7462 - val_recall: 0.6761 - val_MatthewsCorrelationCoefficient: 0.2747
# Epoch 24/30
# 754/754 [==============================] - 219s 291ms/step - loss: 0.3317 - categorical_accuracy: 0.8976 - f1_score: 0.8976 - precision: 0.9178 - recall: 0.8775 - MatthewsCorrelationCoefficient: 0.7269 - val_loss: 1.3703 - val_categorical_accuracy: 0.6966 - val_f1_score: 0.6966 - val_precision: 0.7458 - val_recall: 0.6770 - val_MatthewsCorrelationCoefficient: 0.2743
# Epoch 25/30
# 754/754 [==============================] - 220s 291ms/step - loss: 0.3308 - categorical_accuracy: 0.8965 - f1_score: 0.8965 - precision: 0.9183 - recall: 0.8776 - MatthewsCorrelationCoefficient: 0.7238 - val_loss: 1.3364 - val_categorical_accuracy: 0.6966 - val_f1_score: 0.6966 - val_precision: 0.7481 - val_recall: 0.6763 - val_MatthewsCorrelationCoefficient: 0.2804
# Epoch 26/30
# 754/754 [==============================] - 220s 291ms/step - loss: 0.3262 - categorical_accuracy: 0.8999 - f1_score: 0.8999 - precision: 0.9204 - recall: 0.8808 - MatthewsCorrelationCoefficient: 0.7331 - val_loss: 1.3663 - val_categorical_accuracy: 0.6977 - val_f1_score: 0.6977 - val_precision: 0.7429 - val_recall: 0.6808 - val_MatthewsCorrelationCoefficient: 0.2648
# Epoch 27/30
# 754/754 [==============================] - 218s 289ms/step - loss: 0.3207 - categorical_accuracy: 0.9012 - f1_score: 0.9012 - precision: 0.9218 - recall: 0.8825 - MatthewsCorrelationCoefficient: 0.7367 - val_loss: 1.3605 - val_categorical_accuracy: 0.6965 - val_f1_score: 0.6965 - val_precision: 0.7455 - val_recall: 0.6785 - val_MatthewsCorrelationCoefficient: 0.2736
# Epoch 28/30
# 754/754 [==============================] - 219s 290ms/step - loss: 0.3217 - categorical_accuracy: 0.9016 - f1_score: 0.9016 - precision: 0.9205 - recall: 0.8830 - MatthewsCorrelationCoefficient: 0.7378 - val_loss: 1.3617 - val_categorical_accuracy: 0.6951 - val_f1_score: 0.6951 - val_precision: 0.7440 - val_recall: 0.6766 - val_MatthewsCorrelationCoefficient: 0.2688
# Epoch 29/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.3157 - categorical_accuracy: 0.9022 - f1_score: 0.9022 - precision: 0.9220 - recall: 0.8843 - MatthewsCorrelationCoefficient: 0.7399 - val_loss: 1.3503 - val_categorical_accuracy: 0.6963 - val_f1_score: 0.6963 - val_precision: 0.7504 - val_recall: 0.6744 - val_MatthewsCorrelationCoefficient: 0.2910
# Epoch 30/30
# 754/754 [==============================] - 220s 292ms/step - loss: 0.3143 - categorical_accuracy: 0.9033 - f1_score: 0.9033 - precision: 0.9235 - recall: 0.8852 - MatthewsCorrelationCoefficient: 0.7434 - val_loss: 1.3541 - val_categorical_accuracy: 0.6975 - val_f1_score: 0.6975 - val_precision: 0.7459 - val_recall: 0.6787 - val_MatthewsCorrelationCoefficient: 0.2779

# %%
hist_df = pd.DataFrame(history_resnet.history)

# %%
hist_csv_file = '20220526densenet169lowres1trainclhistory.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
# evaluate the model
loss, accuracy, f1_score, precision, recall, MCC = model.evaluate(validation_generator, verbose=0)

# %%
print ("loss =",loss,"accuracy=",accuracy,"f1=",f1_score,"precision",precision,"recall",recall,"MCC",MCC)
# Out:
# loss = 1.354105830192566 accuracy= 0.6975412964820862 f1= 0.6975412964820862 precision 0.7459016442298889 recall 0.6787216663360596 MCC 0.27793121337890625

# %%
model.save('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/169train1lowres30epochmodelsaved')
# Out:
# 2022-05-30 21:06:14.259160: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/169train1lowres30epochmodelsaved/assets

# %%
#model = keras.models.load_model('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/169train1lowres30epochmodelsaved')

# %%
history_resnet.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'f1_score', 'precision', 'recall', 'MatthewsCorrelationCoefficient', 'val_loss', 'val_categorical_accuracy', 'val_f1_score', 'val_precision', 'val_recall', 'val_MatthewsCorrelationCoefficient'])

# %%
ac = history_resnet.history['categorical_accuracy']
v_ac = history_resnet.history['val_categorical_accuracy']   
lo = history_resnet.history['loss']
v_lo = history_resnet.history['val_loss']
f = history_resnet.history['f1_score']
v_f = history_resnet.history['val_f1_score']
mcc = history_resnet.history['MatthewsCorrelationCoefficient']
v_mcc = history_resnet.history['val_MatthewsCorrelationCoefficient']
epochs = history_resnet.epoch

# %%
plt.figure(figsize=(10,5),frameon=False)
plt.plot(epochs,ac,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_ac,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Accuracy for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,lo,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_lo,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Loss for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,f,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_f,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('f1 for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('f1')
# Out:
# Text(0, 0.5, 'f1')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,mcc,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_mcc,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('MCC for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('MCC')
# Out:
# Text(0, 0.5, 'MCC')
