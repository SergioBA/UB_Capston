# %% [markdown]
# # **Project name: Endoscopic Capsule**

# %% [markdown]
# # **Project configuration**

# %% [markdown]
# ## Folders and files

# %%
## Project folder
collab_path = '/content/'
project_path = collab_path

## Imagery folders
imagery_path = ''
raw_imagery_path = '/raw/'

## Drive folder
drive_path = '/content/drive'
drive_project_path = '/MyDrive/ML_Capstone'
drive_test_path = '/test/'

## Project dataset
file_id = "1_h7juQZBxbwx-JqVBbwaWIEhaNvTY-PW"
file_name = "LMR_Capstone_single.zip"
classes_file = "classes_paper.csv"
#image_size = 336
image_size = 112
image_bands = 3
training_file = 'split_0.csv'
validation_file = 'split_1.csv'

## Training
num_epochs  = 25
retrain = False
#save_model = True
model_name = "model_cnn"
history_name = "history"

# %% [markdown]
# ## Loading Libraries

# %%
# !pip install tensorflow-addons

import os
import shutil

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

from tqdm import tqdm
import cv2

import sklearn.metrics as mtc
from sklearn.metrics import classification_report, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_addons as tfa

import keras.models
import keras.layers
from keras.models import Sequential
from keras.layers import Activation, Dense

# %matplotlib inline
plt.style.use('ggplot')
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (0.16.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)

# %% [markdown]
# ## Environtment information

# %%
print(tf.version.VERSION)
# Out:
# 2.8.0

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Setting-up the environtment (Google-Drive)

# %%
from google.colab import drive
drive.mount(drive_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if not os.path.exists(drive_path+drive_project_path):
  os.makedirs(drive_path+drive_project_path)
if not os.path.exists(drive_path+drive_project_path+drive_test_path):
  os.makedirs(drive_path+drive_project_path+drive_test_path)

# %%
if not os.path.exists(file_name):
  # !pip install gdown
  # !gdown --id $file_id

# %%
#unzip the data
dir = project_path+imagery_path
# !unzip -q -n $file_name -d $dir
dir
# Out:
# '/content/'

# %% [markdown]
# # **Loading and preparing training / validation data**

# %%
training_dir = project_path + imagery_path + os.path.splitext(training_file)[0] + "/"
if not os.path.exists(training_dir):
  os.makedirs(training_dir)

validation_dir = project_path + imagery_path + os.path.splitext(validation_file)[0] + "/"
if not os.path.exists(validation_dir):
  os.makedirs(validation_dir)

# %%
file = project_path + imagery_path + training_file
labels = pd.read_csv(file)   # loading the labels
dir = project_path+imagery_path+'raw/'

for filename, label in zip(labels['filename'], labels['label']):
  if not os.path.exists(training_dir + '/' + label):
    os.makedirs(training_dir + '/' + label)
  shutil.copy(dir + filename, training_dir + '/' + label)
  
  gs_img = cv2.imread(training_dir + '/' + label + '/' + filename)
  gs_res_img = cv2.resize(gs_img, (image_size, image_size))
  cv2.imwrite(training_dir + '/' + label + '/' + filename, gs_res_img)

# %%
file = project_path + imagery_path + validation_file
labels = pd.read_csv(file)   # loading the labels
dir = project_path+imagery_path+'raw/'

for filename, label in zip(labels['filename'], labels['label']):
  if not os.path.exists(validation_dir + '/' + label):
    os.makedirs(validation_dir + '/' + label)
  shutil.copy(dir + filename, validation_dir + '/' + label)

  gs_img = cv2.imread(validation_dir + '/' + label + '/' + filename)
  gs_res_img = cv2.resize(gs_img, (image_size, image_size))
  cv2.imwrite(validation_dir + '/' + label + '/' + filename, gs_res_img)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(training_dir,
                                                    class_mode='categorical',
                                                    target_size=(image_size, image_size))
# Out:
# Found 23061 images belonging to 11 classes.

# %%
# No need to augment validation set
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                              class_mode='categorical',
                                                              target_size=(image_size, image_size))
# Out:
# Found 24100 images belonging to 11 classes.

# %% [markdown]
# # **Training**

# %% [markdown]
# ## DenseNet169

# %%
from tensorflow.keras.applications.densenet import DenseNet169

model = DenseNet169(input_shape=(image_size,image_size,image_bands),include_top = False, weights= 'imagenet')

for layer in model.layers:  
    layer.trainable=False

x = model.layers[-1].output
x = keras.layers.Flatten()(x)
x = keras.layers.Dropout(0.4)(x)      
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dropout(0.2)(x)                  
x = keras.layers.Dense(11, activation='softmax')(x) 
model = keras.Model(model.input, x)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  zero_padding2d_4 (ZeroPadding2  (None, 118, 118, 3)  0          ['input_3[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 56, 56, 64)   9408        ['zero_padding2d_4[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 56, 56, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 56, 56, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 58, 58, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 28, 28, 64)   0           ['zero_padding2d_5[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 28, 28, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 28, 28, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 28, 28, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 28, 28, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 28, 28, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 28, 28, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 28, 28, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 28, 28, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 28, 28, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 28, 28, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 28, 28, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 28, 28, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 28, 28, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 28, 28, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 14, 14, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 14, 14, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 14, 14, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 14, 14, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 14, 14, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 14, 14, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 14, 14, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 14, 14, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 14, 14, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 14, 14, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 14, 14, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 14, 14, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 14, 14, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 14, 14, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 14, 14, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 14, 14, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 14, 14, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 14, 14, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 14, 14, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 14, 14, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 14, 14, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 14, 14, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 14, 14, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 14, 14, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 14, 14, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 14, 14, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 14, 14, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 14, 14, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 14, 14, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 14, 14, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 14, 14, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 14, 14, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 14, 14, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 14, 14, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 14, 14, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 14, 14, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 14, 14, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 14, 14, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 14, 14, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 14, 14, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 14, 14, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 14, 14, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 14, 14, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 14, 14, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 14, 14, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 7, 7, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 7, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 7, 7, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 7, 7, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 7, 7, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 7, 7, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 7, 7, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 7, 7, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 7, 7, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 7, 7, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 7, 7, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 7, 7, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 7, 7, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 7, 7, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 7, 7, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 7, 7, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 7, 7, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  conv5_block25_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 3, 3, 1440)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 3, 3, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 3, 3, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 3, 3, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 3, 3, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 3, 3, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 3, 3, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 3, 3, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 3, 3, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 3, 3, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 3, 3, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 3, 3, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 3, 3, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 3, 3, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 3, 3, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 3, 3, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 3, 3, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 3, 3, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 3, 3, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 3, 3, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 3, 3, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 3, 3, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 3, 3, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 3, 3, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 3, 3, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 3, 3, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 3, 3, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 3, 3, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 3, 3, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 3, 3, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 3, 3, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 3, 3, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 3, 3, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 3, 3, 1664)   0           ['bn[0][0]']
#
#  flatten_2 (Flatten)            (None, 14976)        0           ['relu[0][0]']
#
#  dropout_4 (Dropout)            (None, 14976)        0           ['flatten_2[0][0]']
#
#  dense_4 (Dense)                (None, 256)          3834112     ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 256)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 11)           2827        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 16,479,819
# Trainable params: 3,836,939
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.493754 to fit

# %%
model.compile(optimizer = 'adam', 
              loss = 'categorical_crossentropy', 
              metrics=[tf.keras.metrics.Accuracy(), tfa.metrics.F1Score(num_classes=11, average="micro"), tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.MatthewsCorrelationCoefficient(num_classes=11)])

# %%
model_filepath = drive_path + drive_project_path + drive_test_path +  model_name

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=model_filepath,
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
if retrain:
  model.load_weights(model_filepath)

# %% [markdown]
# ## Fiting the model

# %%
train_history = model.fit(train_generator, 
                          epochs=num_epochs,
                          verbose=1,
                          validation_data=validation_generator)
#                          batch_size=1024,
#                          validation_data=(x_val, y_val),
#                          class_weight=dic_weights,
#                          callbacks=[cp_callback])
# Out:
# Epoch 1/25
# 721/721 [==============================] - 81s 97ms/step - loss: 0.6008 - accuracy: 2.1682e-04 - f1_score: 0.8498 - precision_1: 0.8821 - recall_1: 0.8182 - MatthewsCorrelationCoefficient: 0.6902 - val_loss: 1.2195 - val_accuracy: 3.3949e-05 - val_f1_score: 0.7521 - val_precision_1: 0.7830 - val_recall_1: 0.7196 - val_MatthewsCorrelationCoefficient: 0.3076
# Epoch 2/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.2870 - accuracy: 1.7345e-04 - f1_score: 0.9100 - precision_1: 0.9265 - recall_1: 0.8949 - MatthewsCorrelationCoefficient: 0.8180 - val_loss: 1.3756 - val_accuracy: 3.4327e-04 - val_f1_score: 0.7547 - val_precision_1: 0.7739 - val_recall_1: 0.7364 - val_MatthewsCorrelationCoefficient: 0.2964
# Epoch 3/25
# 721/721 [==============================] - 67s 92ms/step - loss: 0.2274 - accuracy: 7.8054e-04 - f1_score: 0.9268 - precision_1: 0.9416 - recall_1: 0.9153 - MatthewsCorrelationCoefficient: 0.8527 - val_loss: 1.2805 - val_accuracy: 7.9215e-05 - val_f1_score: 0.7366 - val_precision_1: 0.7717 - val_recall_1: 0.6988 - val_MatthewsCorrelationCoefficient: 0.3398
# Epoch 4/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.2130 - accuracy: 0.0014 - f1_score: 0.9302 - precision_1: 0.9425 - recall_1: 0.9201 - MatthewsCorrelationCoefficient: 0.8600 - val_loss: 1.6531 - val_accuracy: 6.6390e-04 - val_f1_score: 0.7042 - val_precision_1: 0.7278 - val_recall_1: 0.6754 - val_MatthewsCorrelationCoefficient: 0.2060
# Epoch 5/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1867 - accuracy: 0.0031 - f1_score: 0.9395 - precision_1: 0.9495 - recall_1: 0.9319 - MatthewsCorrelationCoefficient: 0.8788 - val_loss: 1.6490 - val_accuracy: 2.4519e-04 - val_f1_score: 0.6800 - val_precision_1: 0.7208 - val_recall_1: 0.6357 - val_MatthewsCorrelationCoefficient: 0.2492
# Epoch 6/25
# 721/721 [==============================] - 67s 92ms/step - loss: 0.1760 - accuracy: 0.0040 - f1_score: 0.9425 - precision_1: 0.9514 - recall_1: 0.9338 - MatthewsCorrelationCoefficient: 0.8849 - val_loss: 1.9981 - val_accuracy: 0.0011 - val_f1_score: 0.7368 - val_precision_1: 0.7515 - val_recall_1: 0.7215 - val_MatthewsCorrelationCoefficient: 0.3112
# Epoch 7/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1683 - accuracy: 0.0057 - f1_score: 0.9453 - precision_1: 0.9538 - recall_1: 0.9383 - MatthewsCorrelationCoefficient: 0.8905 - val_loss: 2.1138 - val_accuracy: 0.0015 - val_f1_score: 0.7043 - val_precision_1: 0.7152 - val_recall_1: 0.6893 - val_MatthewsCorrelationCoefficient: 0.3172
# Epoch 8/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1561 - accuracy: 0.0070 - f1_score: 0.9503 - precision_1: 0.9589 - recall_1: 0.9439 - MatthewsCorrelationCoefficient: 0.9007 - val_loss: 1.9135 - val_accuracy: 0.0011 - val_f1_score: 0.7156 - val_precision_1: 0.7323 - val_recall_1: 0.6963 - val_MatthewsCorrelationCoefficient: 0.3213
# Epoch 9/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1465 - accuracy: 0.0084 - f1_score: 0.9527 - precision_1: 0.9589 - recall_1: 0.9472 - MatthewsCorrelationCoefficient: 0.9056 - val_loss: 2.0580 - val_accuracy: 0.0012 - val_f1_score: 0.6714 - val_precision_1: 0.6876 - val_recall_1: 0.6522 - val_MatthewsCorrelationCoefficient: 0.2451
# Epoch 10/25
# 721/721 [==============================] - 67s 92ms/step - loss: 0.1385 - accuracy: 0.0099 - f1_score: 0.9551 - precision_1: 0.9609 - recall_1: 0.9502 - MatthewsCorrelationCoefficient: 0.9104 - val_loss: 2.3014 - val_accuracy: 0.0037 - val_f1_score: 0.7502 - val_precision_1: 0.7583 - val_recall_1: 0.7409 - val_MatthewsCorrelationCoefficient: 0.3043
# Epoch 11/25
# 721/721 [==============================] - 67s 92ms/step - loss: 0.1334 - accuracy: 0.0131 - f1_score: 0.9556 - precision_1: 0.9611 - recall_1: 0.9510 - MatthewsCorrelationCoefficient: 0.9114 - val_loss: 2.1597 - val_accuracy: 0.0029 - val_f1_score: 0.7344 - val_precision_1: 0.7491 - val_recall_1: 0.7171 - val_MatthewsCorrelationCoefficient: 0.3122
# Epoch 12/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1304 - accuracy: 0.0144 - f1_score: 0.9593 - precision_1: 0.9655 - recall_1: 0.9537 - MatthewsCorrelationCoefficient: 0.9189 - val_loss: 2.0426 - val_accuracy: 0.0022 - val_f1_score: 0.7097 - val_precision_1: 0.7220 - val_recall_1: 0.6910 - val_MatthewsCorrelationCoefficient: 0.2676
# Epoch 13/25
# 721/721 [==============================] - 67s 92ms/step - loss: 0.1306 - accuracy: 0.0169 - f1_score: 0.9590 - precision_1: 0.9641 - recall_1: 0.9546 - MatthewsCorrelationCoefficient: 0.9183 - val_loss: 2.3277 - val_accuracy: 0.0042 - val_f1_score: 0.7331 - val_precision_1: 0.7442 - val_recall_1: 0.7227 - val_MatthewsCorrelationCoefficient: 0.3179
# Epoch 14/25
# 721/721 [==============================] - 66s 92ms/step - loss: 0.1118 - accuracy: 0.0219 - f1_score: 0.9629 - precision_1: 0.9677 - recall_1: 0.9596 - MatthewsCorrelationCoefficient: 0.9260 - val_loss: 2.5824 - val_accuracy: 0.0048 - val_f1_score: 0.6922 - val_precision_1: 0.7007 - val_recall_1: 0.6832 - val_MatthewsCorrelationCoefficient: 0.2545
# Epoch 15/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.1175 - accuracy: 0.0234 - f1_score: 0.9620 - precision_1: 0.9669 - recall_1: 0.9574 - MatthewsCorrelationCoefficient: 0.9243 - val_loss: 2.8029 - val_accuracy: 0.0058 - val_f1_score: 0.6991 - val_precision_1: 0.7068 - val_recall_1: 0.6863 - val_MatthewsCorrelationCoefficient: 0.3141
# Epoch 16/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.1133 - accuracy: 0.0275 - f1_score: 0.9631 - precision_1: 0.9676 - recall_1: 0.9595 - MatthewsCorrelationCoefficient: 0.9264 - val_loss: 2.2580 - val_accuracy: 0.0047 - val_f1_score: 0.7237 - val_precision_1: 0.7339 - val_recall_1: 0.7073 - val_MatthewsCorrelationCoefficient: 0.2790
# Epoch 17/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.1089 - accuracy: 0.0307 - f1_score: 0.9653 - precision_1: 0.9689 - recall_1: 0.9619 - MatthewsCorrelationCoefficient: 0.9309 - val_loss: 2.6078 - val_accuracy: 0.0061 - val_f1_score: 0.7116 - val_precision_1: 0.7244 - val_recall_1: 0.6995 - val_MatthewsCorrelationCoefficient: 0.2775
# Epoch 18/25
# 721/721 [==============================] - 69s 95ms/step - loss: 0.1071 - accuracy: 0.0357 - f1_score: 0.9665 - precision_1: 0.9707 - recall_1: 0.9631 - MatthewsCorrelationCoefficient: 0.9334 - val_loss: 2.8973 - val_accuracy: 0.0069 - val_f1_score: 0.7239 - val_precision_1: 0.7365 - val_recall_1: 0.7155 - val_MatthewsCorrelationCoefficient: 0.3098
# Epoch 19/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.1063 - accuracy: 0.0389 - f1_score: 0.9653 - precision_1: 0.9697 - recall_1: 0.9626 - MatthewsCorrelationCoefficient: 0.9310 - val_loss: 2.4899 - val_accuracy: 0.0083 - val_f1_score: 0.7316 - val_precision_1: 0.7432 - val_recall_1: 0.7195 - val_MatthewsCorrelationCoefficient: 0.2844
# Epoch 20/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.0965 - accuracy: 0.0454 - f1_score: 0.9692 - precision_1: 0.9731 - recall_1: 0.9662 - MatthewsCorrelationCoefficient: 0.9387 - val_loss: 2.8923 - val_accuracy: 0.0163 - val_f1_score: 0.7378 - val_precision_1: 0.7443 - val_recall_1: 0.7310 - val_MatthewsCorrelationCoefficient: 0.2719
# Epoch 21/25
# 721/721 [==============================] - 67s 94ms/step - loss: 0.1008 - accuracy: 0.0476 - f1_score: 0.9676 - precision_1: 0.9716 - recall_1: 0.9650 - MatthewsCorrelationCoefficient: 0.9355 - val_loss: 2.8171 - val_accuracy: 0.0160 - val_f1_score: 0.7353 - val_precision_1: 0.7442 - val_recall_1: 0.7271 - val_MatthewsCorrelationCoefficient: 0.3166
# Epoch 22/25
# 721/721 [==============================] - 67s 93ms/step - loss: 0.0939 - accuracy: 0.0496 - f1_score: 0.9694 - precision_1: 0.9732 - recall_1: 0.9660 - MatthewsCorrelationCoefficient: 0.9391 - val_loss: 2.2875 - val_accuracy: 0.0042 - val_f1_score: 0.7178 - val_precision_1: 0.7334 - val_recall_1: 0.6989 - val_MatthewsCorrelationCoefficient: 0.2691
# Epoch 23/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.0962 - accuracy: 0.0505 - f1_score: 0.9694 - precision_1: 0.9731 - recall_1: 0.9671 - MatthewsCorrelationCoefficient: 0.9391 - val_loss: 2.6004 - val_accuracy: 0.0173 - val_f1_score: 0.7537 - val_precision_1: 0.7614 - val_recall_1: 0.7455 - val_MatthewsCorrelationCoefficient: 0.3073
# Epoch 24/25
# 721/721 [==============================] - 67s 94ms/step - loss: 0.0988 - accuracy: 0.0510 - f1_score: 0.9688 - precision_1: 0.9719 - recall_1: 0.9660 - MatthewsCorrelationCoefficient: 0.9380 - val_loss: 2.9957 - val_accuracy: 0.0100 - val_f1_score: 0.6998 - val_precision_1: 0.7077 - val_recall_1: 0.6893 - val_MatthewsCorrelationCoefficient: 0.2726
# Epoch 25/25
# 721/721 [==============================] - 68s 94ms/step - loss: 0.0949 - accuracy: 0.0593 - f1_score: 0.9699 - precision_1: 0.9733 - recall_1: 0.9677 - MatthewsCorrelationCoefficient: 0.9400 - val_loss: 2.8954 - val_accuracy: 0.0137 - val_f1_score: 0.7334 - val_precision_1: 0.7414 - val_recall_1: 0.7259 - val_MatthewsCorrelationCoefficient: 0.3260

# %%
model_filepath = drive_path + drive_project_path + drive_test_path +  model_name
model_filepath
# Out:
# '/content/drive/MyDrive/ML_Capstone/test/model_cnn'

# %%
train_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'f1_score', 'precision_1', 'recall_1', 'MatthewsCorrelationCoefficient', 'val_loss', 'val_accuracy', 'val_f1_score', 'val_precision_1', 'val_recall_1', 'val_MatthewsCorrelationCoefficient'])

# %% [markdown]
# ## Plot history

# %%
ac = train_history.history['accuracy']
v_ac = train_history.history['val_accuracy']   
lo = train_history.history['loss']
v_lo = train_history.history['val_loss']
f = train_history.history['f1_score']
v_f = train_history.history['val_f1_score']
epochs = train_history.epoch

# %%
plt.figure(figsize=(10,5),frameon=False)
plt.plot(epochs,ac,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_ac,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Accuracy for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,lo,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_lo,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Loss for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,f,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_f,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('f1 for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('f1')
# Out:
# Text(0, 0.5, 'f1')

# %% [markdown]
# ## Evaluating the model

# %%
loss, accuracy, f1_score, precision, recall, MCC = model.evaluate(validation_generator, verbose=0)

# %%
print ("loss =",loss,"accuracy=",accuracy,"f1=",f1_score,"precision",precision,"recall",recall,"MCC",MCC)
# Out:
# loss = 2.8953957557678223 accuracy= 0.013726895675063133 f1= 0.733361005783081 precision 0.7414172887802124 recall 0.7258506417274475 MCC 0.32596951723098755

# %% [markdown]
# # Confussion Matrix and Classification Report

# %%
y_pred = model.predict(validation_generator)
y_pred = np.argmax(y_pred, axis=1)

# %%
target_names = sorted(labels['label'].unique())
cr = classification_report(validation_generator.classes, y_pred, target_names=target_names)
print(cr)
#, target_names=target_names))
# Out:
#                       precision    recall  f1-score   support
#
#          Angiectasia       0.00      0.00      0.00        95
#          Blood_fresh       0.00      0.00      0.00       424
#              Erosion       0.01      0.02      0.01       161
#         Erythematous       0.00      0.00      0.00        27
#         Foreign_body       0.00      0.01      0.00       186
#      Ileocecal_valve       0.06      0.14      0.08      1394
#     Lymphangiectasia       0.00      0.00      0.00       368
#               Normal       0.77      0.78      0.77     18485
#              Pylorus       0.03      0.04      0.03       591
# Reduced_mucosal_view       0.06      0.01      0.02      1787
#                Ulcer       0.00      0.00      0.00       582
#
#             accuracy                           0.61     24100
#            macro avg       0.08      0.09      0.08     24100
#         weighted avg       0.60      0.61      0.60     24100

# %%
fig, ax = plt.subplots(figsize=(10, 10))
cm = confusion_matrix(validation_generator.classes, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= list(range(11)))
disp.plot(ax=ax)
