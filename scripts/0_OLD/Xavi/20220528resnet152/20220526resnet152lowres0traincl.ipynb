# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow_addons as tfa

# %%
import keras.models
import keras.layers
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
import numpy as np

# %%
dirsplit0 = "../20220408CAPSULE_DATA/splits/splitslowres/split_0/"

# %%
dirsplit1 = "../20220408CAPSULE_DATA/splits/splitslowres/split_1/"

# %%
#os.listdir(dirsplit0)

# %%
#os.listdir(dirsplit1)

# %%
train_datagen = ImageDataGenerator()

# %%
TRAINING_DIR = dirsplit0
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    class_mode='categorical',
                                                    target_size=(168, 168))
# Out:
# Found 23061 images belonging to 11 classes.

# %%
# No need to augment validation set
validation_datagen = ImageDataGenerator()

# %%
VALIDATION_DIR = dirsplit1
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              class_mode='categorical',
                                                              target_size=(168, 168))
# Out:
# Found 24100 images belonging to 11 classes.

# %%
# for ims, labs in train_generator:
#     print(ims.shape)
#     break

# %% [markdown]
# ## ResNet152

# %%
#from tensorflow.keras.applications.resnet50 import ResNet50

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_MatthewsCorrelationCoefficient', patience=3)

# %%
from tensorflow.keras.applications.resnet import ResNet152

# %%
pre_trained_model = ResNet152(input_shape=(168,168,3), include_top=False, weights= 'imagenet', pooling='avg')
# Out:
# 2022-05-28 06:30:50.814433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:50.860853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:50.861102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:50.862943: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:50.863161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:50.863359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:51.496252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:51.496475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:51.496664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 06:30:51.496816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3047 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1

# %%
for layer in pre_trained_model.layers:  
    layer.trainable=False

# %%
last_layer = pre_trained_model.get_layer('conv4_block6_out')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 11, 11, 1024)

# %%
inputs = keras.layers.Input((168, 168, 3))
x = tf.keras.applications.resnet50.preprocess_input(inputs) # Preprocessing layer, normalization -1 1
x = pre_trained_model(x)

## Aquestes capes son opcionals
x = keras.layers.Dropout(0.4)(x)      
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dropout(0.2)(x)   

out = keras.layers.Dense(11, activation='softmax')(x)           
model = keras.Model(inputs=inputs, outputs=out) 

model.compile(optimizer = tf.optimizers.SGD(learning_rate=0.001),
              loss = tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy(), 
                       tfa.metrics.F1Score(num_classes=11, average="micro"), 
                       tf.keras.metrics.Precision(), 
                       tf.keras.metrics.Recall(), 
                       tfa.metrics.MatthewsCorrelationCoefficient(num_classes=11)])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 168, 168, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 168, 168, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 168, 168, 3)      0
#
#  resnet152 (Functional)      (None, 2048)              58370944
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 58,898,315
# Trainable params: 527,371
# Non-trainable params: 58,370,944
# _________________________________________________________________

# %%
history_resnet = model.fit(train_generator,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/30
# 2022-05-28 06:31:19.524839: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 721/721 [==============================] - 571s 776ms/step - loss: 1.1248 - categorical_accuracy: 0.6915 - f1_score: 0.6915 - precision: 0.7481 - recall: 0.6203 - MatthewsCorrelationCoefficient: 0.2681 - val_loss: 0.8625 - val_categorical_accuracy: 0.7522 - val_f1_score: 0.7522 - val_precision: 0.8131 - val_recall: 0.7084 - val_MatthewsCorrelationCoefficient: 0.2199
# Epoch 2/30
# 721/721 [==============================] - 553s 767ms/step - loss: 0.8184 - categorical_accuracy: 0.7597 - f1_score: 0.7597 - precision: 0.8124 - recall: 0.7011 - MatthewsCorrelationCoefficient: 0.4541 - val_loss: 0.8930 - val_categorical_accuracy: 0.7307 - val_f1_score: 0.7307 - val_precision: 0.7786 - val_recall: 0.6832 - val_MatthewsCorrelationCoefficient: 0.2435
# Epoch 3/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.7221 - categorical_accuracy: 0.7885 - f1_score: 0.7885 - precision: 0.8336 - recall: 0.7373 - MatthewsCorrelationCoefficient: 0.5311 - val_loss: 0.8989 - val_categorical_accuracy: 0.7338 - val_f1_score: 0.7338 - val_precision: 0.7811 - val_recall: 0.6839 - val_MatthewsCorrelationCoefficient: 0.2450
# Epoch 4/30
# 721/721 [==============================] - 552s 766ms/step - loss: 0.6556 - categorical_accuracy: 0.8064 - f1_score: 0.8064 - precision: 0.8485 - recall: 0.7626 - MatthewsCorrelationCoefficient: 0.5775 - val_loss: 0.9186 - val_categorical_accuracy: 0.7307 - val_f1_score: 0.7307 - val_precision: 0.7707 - val_recall: 0.6865 - val_MatthewsCorrelationCoefficient: 0.2455
# Epoch 5/30
# 721/721 [==============================] - 553s 767ms/step - loss: 0.6098 - categorical_accuracy: 0.8181 - f1_score: 0.8181 - precision: 0.8563 - recall: 0.7796 - MatthewsCorrelationCoefficient: 0.6064 - val_loss: 0.9596 - val_categorical_accuracy: 0.7137 - val_f1_score: 0.7137 - val_precision: 0.7546 - val_recall: 0.6737 - val_MatthewsCorrelationCoefficient: 0.2429
# Epoch 6/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.5819 - categorical_accuracy: 0.8270 - f1_score: 0.8270 - precision: 0.8646 - recall: 0.7880 - MatthewsCorrelationCoefficient: 0.6287 - val_loss: 0.9436 - val_categorical_accuracy: 0.7181 - val_f1_score: 0.7181 - val_precision: 0.7633 - val_recall: 0.6729 - val_MatthewsCorrelationCoefficient: 0.2533
# Epoch 7/30
# 721/721 [==============================] - 554s 769ms/step - loss: 0.5502 - categorical_accuracy: 0.8335 - f1_score: 0.8335 - precision: 0.8692 - recall: 0.7993 - MatthewsCorrelationCoefficient: 0.6439 - val_loss: 0.9604 - val_categorical_accuracy: 0.7158 - val_f1_score: 0.7158 - val_precision: 0.7586 - val_recall: 0.6738 - val_MatthewsCorrelationCoefficient: 0.2577
# Epoch 8/30
# 721/721 [==============================] - 554s 769ms/step - loss: 0.5298 - categorical_accuracy: 0.8387 - f1_score: 0.8387 - precision: 0.8723 - recall: 0.8069 - MatthewsCorrelationCoefficient: 0.6570 - val_loss: 0.9637 - val_categorical_accuracy: 0.7216 - val_f1_score: 0.7216 - val_precision: 0.7600 - val_recall: 0.6834 - val_MatthewsCorrelationCoefficient: 0.2548
# Epoch 9/30
# 721/721 [==============================] - 552s 766ms/step - loss: 0.5067 - categorical_accuracy: 0.8437 - f1_score: 0.8437 - precision: 0.8770 - recall: 0.8144 - MatthewsCorrelationCoefficient: 0.6687 - val_loss: 0.9871 - val_categorical_accuracy: 0.7098 - val_f1_score: 0.7098 - val_precision: 0.7514 - val_recall: 0.6667 - val_MatthewsCorrelationCoefficient: 0.2698
# Epoch 10/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.4934 - categorical_accuracy: 0.8479 - f1_score: 0.8479 - precision: 0.8794 - recall: 0.8178 - MatthewsCorrelationCoefficient: 0.6788 - val_loss: 0.9740 - val_categorical_accuracy: 0.7151 - val_f1_score: 0.7151 - val_precision: 0.7515 - val_recall: 0.6790 - val_MatthewsCorrelationCoefficient: 0.2660
# Epoch 11/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.4824 - categorical_accuracy: 0.8510 - f1_score: 0.8510 - precision: 0.8825 - recall: 0.8220 - MatthewsCorrelationCoefficient: 0.6859 - val_loss: 0.9900 - val_categorical_accuracy: 0.7105 - val_f1_score: 0.7105 - val_precision: 0.7488 - val_recall: 0.6737 - val_MatthewsCorrelationCoefficient: 0.2696
# Epoch 12/30
# 721/721 [==============================] - 555s 770ms/step - loss: 0.4607 - categorical_accuracy: 0.8583 - f1_score: 0.8583 - precision: 0.8872 - recall: 0.8285 - MatthewsCorrelationCoefficient: 0.7021 - val_loss: 0.9700 - val_categorical_accuracy: 0.7187 - val_f1_score: 0.7187 - val_precision: 0.7564 - val_recall: 0.6835 - val_MatthewsCorrelationCoefficient: 0.2688
# Epoch 13/30
# 721/721 [==============================] - 554s 769ms/step - loss: 0.4493 - categorical_accuracy: 0.8588 - f1_score: 0.8588 - precision: 0.8882 - recall: 0.8319 - MatthewsCorrelationCoefficient: 0.7035 - val_loss: 0.9885 - val_categorical_accuracy: 0.7169 - val_f1_score: 0.7169 - val_precision: 0.7565 - val_recall: 0.6794 - val_MatthewsCorrelationCoefficient: 0.2792
# Epoch 14/30
# 721/721 [==============================] - 553s 768ms/step - loss: 0.4422 - categorical_accuracy: 0.8627 - f1_score: 0.8627 - precision: 0.8901 - recall: 0.8367 - MatthewsCorrelationCoefficient: 0.7124 - val_loss: 1.0053 - val_categorical_accuracy: 0.7084 - val_f1_score: 0.7084 - val_precision: 0.7464 - val_recall: 0.6739 - val_MatthewsCorrelationCoefficient: 0.2781
# Epoch 15/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.4316 - categorical_accuracy: 0.8670 - f1_score: 0.8670 - precision: 0.8939 - recall: 0.8413 - MatthewsCorrelationCoefficient: 0.7219 - val_loss: 0.9981 - val_categorical_accuracy: 0.7166 - val_f1_score: 0.7166 - val_precision: 0.7540 - val_recall: 0.6817 - val_MatthewsCorrelationCoefficient: 0.2795
# Epoch 16/30
# 721/721 [==============================] - 552s 766ms/step - loss: 0.4196 - categorical_accuracy: 0.8672 - f1_score: 0.8672 - precision: 0.8932 - recall: 0.8429 - MatthewsCorrelationCoefficient: 0.7227 - val_loss: 1.0127 - val_categorical_accuracy: 0.7112 - val_f1_score: 0.7112 - val_precision: 0.7504 - val_recall: 0.6748 - val_MatthewsCorrelationCoefficient: 0.2794
# Epoch 17/30
# 721/721 [==============================] - 552s 766ms/step - loss: 0.4058 - categorical_accuracy: 0.8734 - f1_score: 0.8734 - precision: 0.8984 - recall: 0.8477 - MatthewsCorrelationCoefficient: 0.7363 - val_loss: 1.0178 - val_categorical_accuracy: 0.7125 - val_f1_score: 0.7125 - val_precision: 0.7481 - val_recall: 0.6807 - val_MatthewsCorrelationCoefficient: 0.2844
# Epoch 18/30
# 721/721 [==============================] - 553s 767ms/step - loss: 0.4047 - categorical_accuracy: 0.8745 - f1_score: 0.8745 - precision: 0.8989 - recall: 0.8502 - MatthewsCorrelationCoefficient: 0.7387 - val_loss: 1.0346 - val_categorical_accuracy: 0.7071 - val_f1_score: 0.7071 - val_precision: 0.7456 - val_recall: 0.6717 - val_MatthewsCorrelationCoefficient: 0.2943
# Epoch 19/30
# 721/721 [==============================] - 556s 771ms/step - loss: 0.3967 - categorical_accuracy: 0.8756 - f1_score: 0.8756 - precision: 0.8995 - recall: 0.8520 - MatthewsCorrelationCoefficient: 0.7415 - val_loss: 1.0316 - val_categorical_accuracy: 0.7130 - val_f1_score: 0.7130 - val_precision: 0.7472 - val_recall: 0.6818 - val_MatthewsCorrelationCoefficient: 0.2868
# Epoch 20/30
# 721/721 [==============================] - 554s 769ms/step - loss: 0.3888 - categorical_accuracy: 0.8795 - f1_score: 0.8795 - precision: 0.9031 - recall: 0.8545 - MatthewsCorrelationCoefficient: 0.7498 - val_loss: 1.0200 - val_categorical_accuracy: 0.7174 - val_f1_score: 0.7174 - val_precision: 0.7507 - val_recall: 0.6882 - val_MatthewsCorrelationCoefficient: 0.2849
# Epoch 21/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.3797 - categorical_accuracy: 0.8808 - f1_score: 0.8808 - precision: 0.9049 - recall: 0.8596 - MatthewsCorrelationCoefficient: 0.7528 - val_loss: 1.0193 - val_categorical_accuracy: 0.7217 - val_f1_score: 0.7217 - val_precision: 0.7515 - val_recall: 0.6939 - val_MatthewsCorrelationCoefficient: 0.2843
# Epoch 22/30
# 721/721 [==============================] - 553s 767ms/step - loss: 0.3717 - categorical_accuracy: 0.8845 - f1_score: 0.8845 - precision: 0.9058 - recall: 0.8623 - MatthewsCorrelationCoefficient: 0.7605 - val_loss: 1.0380 - val_categorical_accuracy: 0.7138 - val_f1_score: 0.7138 - val_precision: 0.7506 - val_recall: 0.6807 - val_MatthewsCorrelationCoefficient: 0.2886
# Epoch 23/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.3669 - categorical_accuracy: 0.8860 - f1_score: 0.8860 - precision: 0.9078 - recall: 0.8635 - MatthewsCorrelationCoefficient: 0.7645 - val_loss: 1.0773 - val_categorical_accuracy: 0.7037 - val_f1_score: 0.7037 - val_precision: 0.7391 - val_recall: 0.6722 - val_MatthewsCorrelationCoefficient: 0.3034
# Epoch 24/30
# 721/721 [==============================] - 552s 767ms/step - loss: 0.3596 - categorical_accuracy: 0.8874 - f1_score: 0.8874 - precision: 0.9096 - recall: 0.8661 - MatthewsCorrelationCoefficient: 0.7672 - val_loss: 1.0582 - val_categorical_accuracy: 0.7105 - val_f1_score: 0.7105 - val_precision: 0.7448 - val_recall: 0.6814 - val_MatthewsCorrelationCoefficient: 0.2947
# Epoch 25/30
# 721/721 [==============================] - 553s 767ms/step - loss: 0.3608 - categorical_accuracy: 0.8860 - f1_score: 0.8860 - precision: 0.9082 - recall: 0.8658 - MatthewsCorrelationCoefficient: 0.7647 - val_loss: 1.0678 - val_categorical_accuracy: 0.7065 - val_f1_score: 0.7065 - val_precision: 0.7424 - val_recall: 0.6759 - val_MatthewsCorrelationCoefficient: 0.2939
# Epoch 26/30
# 721/721 [==============================] - 559s 776ms/step - loss: 0.3522 - categorical_accuracy: 0.8908 - f1_score: 0.8908 - precision: 0.9114 - recall: 0.8705 - MatthewsCorrelationCoefficient: 0.7747 - val_loss: 1.0996 - val_categorical_accuracy: 0.7004 - val_f1_score: 0.7004 - val_precision: 0.7361 - val_recall: 0.6646 - val_MatthewsCorrelationCoefficient: 0.3089
# Epoch 27/30
# 721/721 [==============================] - 556s 772ms/step - loss: 0.3454 - categorical_accuracy: 0.8908 - f1_score: 0.8908 - precision: 0.9128 - recall: 0.8689 - MatthewsCorrelationCoefficient: 0.7749 - val_loss: 1.0604 - val_categorical_accuracy: 0.7144 - val_f1_score: 0.7144 - val_precision: 0.7436 - val_recall: 0.6884 - val_MatthewsCorrelationCoefficient: 0.2934
# Epoch 28/30
# 721/721 [==============================] - 555s 770ms/step - loss: 0.3404 - categorical_accuracy: 0.8906 - f1_score: 0.8906 - precision: 0.9128 - recall: 0.8722 - MatthewsCorrelationCoefficient: 0.7747 - val_loss: 1.0692 - val_categorical_accuracy: 0.7110 - val_f1_score: 0.7110 - val_precision: 0.7424 - val_recall: 0.6829 - val_MatthewsCorrelationCoefficient: 0.2980
# Epoch 29/30
# 721/721 [==============================] - 555s 770ms/step - loss: 0.3337 - categorical_accuracy: 0.8951 - f1_score: 0.8951 - precision: 0.9161 - recall: 0.8751 - MatthewsCorrelationCoefficient: 0.7843 - val_loss: 1.0654 - val_categorical_accuracy: 0.7135 - val_f1_score: 0.7135 - val_precision: 0.7468 - val_recall: 0.6842 - val_MatthewsCorrelationCoefficient: 0.3002
# Epoch 30/30
# 721/721 [==============================] - 556s 772ms/step - loss: 0.3286 - categorical_accuracy: 0.8968 - f1_score: 0.8968 - precision: 0.9170 - recall: 0.8785 - MatthewsCorrelationCoefficient: 0.7880 - val_loss: 1.0622 - val_categorical_accuracy: 0.7173 - val_f1_score: 0.7173 - val_precision: 0.7494 - val_recall: 0.6894 - val_MatthewsCorrelationCoefficient: 0.3025

# %%
# evaluate the model
loss, accuracy, f1_score, precision, recall, MCC = model.evaluate(validation_generator, verbose=0)

# %%
print ("loss =",loss,"accuracy=",accuracy,"f1=",f1_score,"precision",precision,"recall",recall,"MCC",MCC)
# Out:
# loss = 1.062199592590332 accuracy= 0.7173029184341431 f1= 0.7173029780387878 precision 0.749357283115387 recall 0.6893776059150696 MCC 0.30247050523757935

# %%
model.save('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train0lowres30epochmodelsaved')
# Out:
# 2022-05-28 11:16:50.648905: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train0lowres30epochmodelsaved/assets

# %%
#model = keras.models.load_model('/home/javier/Documents/dsub/20220408CAPSTONE_CAPSULE/20220517PereGilabert/152train0lowres30epochmodelsaved')
# Out:
# 2022-05-28 16:52:24.459781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:24.500073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:24.500303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:24.529410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:24.530005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:24.530474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:25.122566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:25.122789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:25.122977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-28 16:52:25.123129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3027 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1

# %%
history_resnet.history.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 history_resnet.history.keys()
#
# NameError: name 'history_resnet' is not defined

# %%
ac = history_resnet.history['categorical_accuracy']
v_ac = history_resnet.history['val_categorical_accuracy']   
lo = history_resnet.history['loss']
v_lo = history_resnet.history['val_loss']
f = history_resnet.history['f1_score']
v_f = history_resnet.history['val_f1_score']
mcc = history_resnet.history['MatthewsCorrelationCoefficient']
v_mcc = history_resnet.history['val_MatthewsCorrelationCoefficient']
epochs = history_resnet.epoch

# %%
plt.figure(figsize=(10,5),frameon=False)
plt.plot(epochs,ac,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_ac,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Accuracy for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,lo,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_lo,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('Loss for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,f,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_f,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('f1 for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('f1')
# Out:
# Text(0, 0.5, 'f1')

# %%
plt.figure(figsize=(10,5))
plt.plot(epochs,mcc,c='b',ls='-.',lw='4',label='Training')
plt.plot(epochs,v_mcc,c='r',ls='-.',lw='4',label='Validation')
plt.legend()
plt.title('MCC for Training and Validation over the epochs')
plt.xlabel('Epochs')
plt.ylabel('MCC')
# Out:
# Text(0, 0.5, 'MCC')
